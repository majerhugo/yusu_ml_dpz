# %% [markdown]
# ##### Reference raster probably must be the same size (width / height) as the imagery, resolution also

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio as rio
import numpy as np
import os
from sklearn.model_selection import StratifiedShuffleSplit
from torch.utils.data import Subset
from rasterio.windows import Window
from rasterio.transform import Affine
import random
import matplotlib.pyplot as plt
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.autograd import Variable
from torchvision.transforms import v2 as transforms

torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
random.seed(0)
torch.cuda.manual_seed_all(0)
torch.backends.cudnn.benchmark = False

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# LEN TILING SNIMKU NA 32X32 STRIDE 1
class PatchDataset(Dataset):
    def __init__(self, image_path, patch_size, stride, offset_left=0, offset_top=0):
        """
        Dataset for extracting patches from an image and corresponding labels from a reference raster.

        Args:
            image_path (str): Path to the Sentinel image (features).
            reference_path (str): Path to the reference raster (labels).
            patch_size (int): Size of the square patches (in pixels).
            stride (int): Step size for sliding the window.
            offset_left (int): Number of pixels to ignore from the left edge of the image.
            offset_top (int): Number of pixels to ignore from the top edge of the image.
        """
        self.image_path = image_path
        self.patch_size = patch_size
        self.stride = stride
        self.offset_left = offset_left
        self.offset_top = offset_top

        # Open the feature and reference rasters
        self.src_features = rio.open(image_path)

        # Adjust dimensions based on offsets
        self.width = self.src_features.width - offset_left
        self.height = self.src_features.height - offset_top
        self.num_bands = self.src_features.count

        # Precompute patch positions (accounting for offsets)
        self.patches = [
            (row, col)
            for row in range(0, self.height - patch_size + 1, stride)
            for col in range(0, self.width - patch_size + 1, stride)
        ]

    def __len__(self):
        return len(self.patches)

    def __getitem__(self, idx):
        row, col = self.patches[idx]

        # Adjust row and col to account for offsets
        row += self.offset_top
        col += self.offset_left

        # Extract the image patch
        window = rio.windows.Window(col, row, self.patch_size, self.patch_size)
        patch_features = self.src_features.read(window=window)  # Shape: (bands, patch_size, patch_size)

        # Return the patch and its label
        return torch.tensor(patch_features, dtype=torch.float32)


dirs=[r'32x32_stride1_left0_top0_all1',
      r'32x32_stride1_left0_top0_all2',
      r'32x32_stride1_left0_top0_all3',
      r'32x32_stride1_left0_top0_all4',
      r'32x32_stride1_left0_top0_all5',
      r'32x32_stride1_left0_top0_all6',
      r'32x32_stride1_left0_top0_all7',
      r'32x32_stride1_left0_top0_all8',
      r'32x32_stride1_left0_top0_all9',
      r'32x32_stride1_left0_top0_all10']

start = time.time()


# SETTINGS
image_path = r"composite_subset_with_height.tif"  # Path to Sentinel image (features)
patch_size = 32
stride = 1
offset_left = 0
offset_top = 0
#output_dir_all = r"32x32_stride1_left0_top0_all"
#output_dir_valid = r"32x32_stride1_left0_top0_GT"
dir_index = 0

# Create output directories
os.makedirs(dirs[dir_index], exist_ok=True)

# Initialize the dataset
dataset = PatchDataset(
    image_path=image_path,  
    patch_size=patch_size, 
    stride=stride,
    offset_left=offset_left, 
    offset_top=offset_top
)

for idx, features in enumerate(dataset):
    # Save every generated tile
    all_tile_path = os.path.join(dirs[dir_index], f"tile_{str(idx).zfill(20)}.pt")
    torch.save(features, all_tile_path)

    # Log progress
    if idx % 10000 == 0:
        print(f"Processed tile {idx}")

    if idx % 6500000 == 0 and idx != 0:
        dir_index += 1
        os.makedirs(dirs[dir_index], exist_ok=True)

print('---')
time_elapsed = time.time() - start
print('Tile creation took {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
# Out:
# Processed tile 0
# Processed tile 10000
# Processed tile 20000
# Processed tile 30000
# Processed tile 40000
# Processed tile 50000
# Processed tile 60000
# Processed tile 70000
# Processed tile 80000
# Processed tile 90000
# Processed tile 100000
# Processed tile 110000
# Processed tile 120000
# Processed tile 130000
# Processed tile 140000
# Processed tile 150000
# Processed tile 160000
# Processed tile 170000
# Processed tile 180000
# Processed tile 190000
# Processed tile 200000
# Processed tile 210000
# Processed tile 220000
# Processed tile 230000
# Processed tile 240000
# Processed tile 250000
# Processed tile 260000
# Processed tile 270000
# Processed tile 280000
# Processed tile 290000
# Processed tile 300000
# Processed tile 310000
# Processed tile 320000
# Processed tile 330000
# Processed tile 340000
# Processed tile 350000
# Processed tile 360000
# Processed tile 370000
# Processed tile 380000
# Processed tile 390000
# Processed tile 400000
# Processed tile 410000
# Processed tile 420000
# Processed tile 430000
# Processed tile 440000
# Processed tile 450000
# Processed tile 460000
# Processed tile 470000
# Processed tile 480000
# Processed tile 490000
# Processed tile 500000
# Processed tile 510000
# Processed tile 520000
# Processed tile 530000
# Processed tile 540000
# Processed tile 550000
# Processed tile 560000
# Processed tile 570000
# Processed tile 580000
# Processed tile 590000
# Processed tile 600000
# Processed tile 610000
# Processed tile 620000
# Processed tile 630000
# Processed tile 640000
# Processed tile 650000
# Processed tile 660000
# Processed tile 670000
# Processed tile 680000
# Processed tile 690000
# Processed tile 700000
# Processed tile 710000
# Processed tile 720000
# Processed tile 730000
# Processed tile 740000
# Processed tile 750000
# Processed tile 760000
# Processed tile 770000
# Processed tile 780000
# Processed tile 790000
# Processed tile 800000
# Processed tile 810000
# Processed tile 820000
# Processed tile 830000
# Processed tile 840000
# Processed tile 850000
# Processed tile 860000
# Processed tile 870000
# Processed tile 880000
# Processed tile 890000
# Processed tile 900000
# Processed tile 910000
# Processed tile 920000
# Processed tile 930000
# Processed tile 940000
# Processed tile 950000
# Processed tile 960000
# Processed tile 970000
# Processed tile 980000
# Processed tile 990000
# Processed tile 1000000
# Processed tile 1010000
# Processed tile 1020000
# Processed tile 1030000
# Processed tile 1040000
# Processed tile 1050000
# Processed tile 1060000
# Processed tile 1070000
# Processed tile 1080000
# Processed tile 1090000
# Processed tile 1100000
# Processed tile 1110000
# Processed tile 1120000
# Processed tile 1130000
# Processed tile 1140000
# Processed tile 1150000
# Processed tile 1160000
# Processed tile 1170000
# Processed tile 1180000
# Processed tile 1190000
# Processed tile 1200000
# Processed tile 1210000
# Processed tile 1220000
# Processed tile 1230000
# Processed tile 1240000
# Processed tile 1250000
# Processed tile 1260000
# Processed tile 1270000
# Processed tile 1280000
# Processed tile 1290000
# Processed tile 1300000
# Processed tile 1310000
# Processed tile 1320000
# Processed tile 1330000
# Processed tile 1340000
# Processed tile 1350000
# Processed tile 1360000
# Processed tile 1370000
# Processed tile 1380000
# Processed tile 1390000
# Processed tile 1400000
# Processed tile 1410000
# Processed tile 1420000
# Processed tile 1430000
# Processed tile 1440000
# Processed tile 1450000
# Processed tile 1460000
# Processed tile 1470000
# Processed tile 1480000
# Processed tile 1490000
# Processed tile 1500000
# Processed tile 1510000
# Processed tile 1520000
# Processed tile 1530000
# Processed tile 1540000
# Processed tile 1550000
# Processed tile 1560000
# Processed tile 1570000
# Processed tile 1580000
# Processed tile 1590000
# Processed tile 1600000
# Processed tile 1610000
# Processed tile 1620000
# Processed tile 1630000
# Processed tile 1640000
# Processed tile 1650000
# Processed tile 1660000
# Processed tile 1670000
# Processed tile 1680000
# Processed tile 1690000
# Processed tile 1700000
# Processed tile 1710000
# Processed tile 1720000
# Processed tile 1730000
# Processed tile 1740000
# Processed tile 1750000
# Processed tile 1760000
# Processed tile 1770000
# Processed tile 1780000
# Processed tile 1790000
# Processed tile 1800000
# Processed tile 1810000
# Processed tile 1820000
# Processed tile 1830000
# Processed tile 1840000
# Processed tile 1850000
# Processed tile 1860000
# Processed tile 1870000
# Processed tile 1880000
# Processed tile 1890000
# Processed tile 1900000
# Processed tile 1910000
# Processed tile 1920000
# Processed tile 1930000
# Processed tile 1940000
# Processed tile 1950000
# Processed tile 1960000
# Processed tile 1970000
# Processed tile 1980000
# Processed tile 1990000
# Processed tile 2000000
# Processed tile 2010000
# Processed tile 2020000
# Processed tile 2030000
# Processed tile 2040000
# Processed tile 2050000
# Processed tile 2060000
# Processed tile 2070000
# Processed tile 2080000
# Processed tile 2090000
# Processed tile 2100000
# Processed tile 2110000
# Processed tile 2120000
# Processed tile 2130000
# Processed tile 2140000
# Processed tile 2150000
# Processed tile 2160000
# Processed tile 2170000
# Processed tile 2180000
# Processed tile 2190000
# Processed tile 2200000
# Processed tile 2210000
# Processed tile 2220000
# Processed tile 2230000
# Processed tile 2240000
# Processed tile 2250000
# Processed tile 2260000
# Processed tile 2270000
# Processed tile 2280000
# Processed tile 2290000
# Processed tile 2300000
# Processed tile 2310000
# Processed tile 2320000
# Processed tile 2330000
# Processed tile 2340000
# Processed tile 2350000
# Processed tile 2360000
# Processed tile 2370000
# Processed tile 2380000
# Processed tile 2390000
# Processed tile 2400000
# Processed tile 2410000
# Processed tile 2420000
# Processed tile 2430000
# Processed tile 2440000
# Processed tile 2450000
# Processed tile 2460000
# Processed tile 2470000
# Processed tile 2480000
# Processed tile 2490000
# Processed tile 2500000
# Processed tile 2510000
# Processed tile 2520000
# Processed tile 2530000
# Processed tile 2540000
# Processed tile 2550000
# Processed tile 2560000
# Processed tile 2570000
# Processed tile 2580000
# Processed tile 2590000
# Processed tile 2600000
# Processed tile 2610000
# Processed tile 2620000
# Processed tile 2630000
# Processed tile 2640000
# Processed tile 2650000
# Processed tile 2660000
# Processed tile 2670000
# Processed tile 2680000
# Processed tile 2690000
# Processed tile 2700000
# Processed tile 2710000
# Processed tile 2720000
# Processed tile 2730000
# Processed tile 2740000
# Processed tile 2750000
# Processed tile 2760000
# Processed tile 2770000
# Processed tile 2780000
# Processed tile 2790000
# Processed tile 2800000
# Processed tile 2810000
# Processed tile 2820000
# Processed tile 2830000
# Processed tile 2840000
# Processed tile 2850000
# Processed tile 2860000
# Processed tile 2870000
# Processed tile 2880000
# Processed tile 2890000
# Processed tile 2900000
# Processed tile 2910000
# Processed tile 2920000
# Processed tile 2930000
# Processed tile 2940000
# Processed tile 2950000
# Processed tile 2960000
# Processed tile 2970000
# Processed tile 2980000
# Processed tile 2990000
# Processed tile 3000000
# Processed tile 3010000
# Processed tile 3020000
# Processed tile 3030000
# Processed tile 3040000
# Processed tile 3050000
# Processed tile 3060000
# Processed tile 3070000
# Processed tile 3080000
# Processed tile 3090000
# Processed tile 3100000
# Processed tile 3110000
# Processed tile 3120000
# Processed tile 3130000
# Processed tile 3140000
# Processed tile 3150000
# Processed tile 3160000
# Processed tile 3170000
# Processed tile 3180000
# Processed tile 3190000
# Processed tile 3200000
# Processed tile 3210000
# Processed tile 3220000
# Processed tile 3230000
# Processed tile 3240000
# Processed tile 3250000
# Processed tile 3260000
# Processed tile 3270000
# Processed tile 3280000
# Processed tile 3290000
# Processed tile 3300000
# Processed tile 3310000
# Processed tile 3320000
# Processed tile 3330000
# Processed tile 3340000
# Processed tile 3350000
# Processed tile 3360000
# Processed tile 3370000
# Processed tile 3380000
# Processed tile 3390000
# Processed tile 3400000
# Processed tile 3410000
# Processed tile 3420000
# Processed tile 3430000
# Processed tile 3440000
# Processed tile 3450000
# Processed tile 3460000
# Processed tile 3470000
# Processed tile 3480000
# Processed tile 3490000
# Processed tile 3500000
# Processed tile 3510000
# Processed tile 3520000
# Processed tile 3530000
# Processed tile 3540000
# Processed tile 3550000
# Processed tile 3560000
# Processed tile 3570000
# Processed tile 3580000
# Processed tile 3590000
# Processed tile 3600000
# Processed tile 3610000
# Processed tile 3620000
# Processed tile 3630000
# Processed tile 3640000
# Processed tile 3650000
# Processed tile 3660000
# Processed tile 3670000
# Processed tile 3680000
# Processed tile 3690000
# Processed tile 3700000
# Processed tile 3710000
# Processed tile 3720000
# Processed tile 3730000
# Processed tile 3740000
# Processed tile 3750000
# Processed tile 3760000
# Processed tile 3770000
# Processed tile 3780000
# Processed tile 3790000
# Processed tile 3800000
# Processed tile 3810000
# Processed tile 3820000
# Processed tile 3830000
# Processed tile 3840000
# Processed tile 3850000
# Processed tile 3860000
# Processed tile 3870000
# Processed tile 3880000
# Processed tile 3890000
# Processed tile 3900000
# Processed tile 3910000
# Processed tile 3920000
# Processed tile 3930000
# Processed tile 3940000
# Processed tile 3950000
# Processed tile 3960000
# Processed tile 3970000
# Processed tile 3980000
# Processed tile 3990000
# Processed tile 4000000
# Processed tile 4010000
# Processed tile 4020000
# Processed tile 4030000
# Processed tile 4040000
# Processed tile 4050000
# Processed tile 4060000
# Processed tile 4070000
# Processed tile 4080000
# Processed tile 4090000
# Processed tile 4100000
# Processed tile 4110000
# Processed tile 4120000
# Processed tile 4130000
# Processed tile 4140000
# Processed tile 4150000
# Processed tile 4160000
# Processed tile 4170000
# Processed tile 4180000
# Processed tile 4190000
# Processed tile 4200000
# Processed tile 4210000
# Processed tile 4220000
# Processed tile 4230000
# Processed tile 4240000
# Processed tile 4250000
# Processed tile 4260000
# Processed tile 4270000
# Processed tile 4280000
# Processed tile 4290000
# Processed tile 4300000
# Processed tile 4310000
# Processed tile 4320000
# Processed tile 4330000
# Processed tile 4340000
# Processed tile 4350000
# Processed tile 4360000
# Processed tile 4370000
# Processed tile 4380000
# Processed tile 4390000
# Processed tile 4400000
# Processed tile 4410000
# Processed tile 4420000
# Processed tile 4430000
# Processed tile 4440000
# Processed tile 4450000
# Processed tile 4460000
# Processed tile 4470000
# Processed tile 4480000
# Processed tile 4490000
# Processed tile 4500000
# Processed tile 4510000
# Processed tile 4520000
# Processed tile 4530000
# Processed tile 4540000
# Processed tile 4550000
# Processed tile 4560000
# Processed tile 4570000
# Processed tile 4580000
# Processed tile 4590000
# Processed tile 4600000
# Processed tile 4610000
# Processed tile 4620000
# Processed tile 4630000
# Processed tile 4640000
# Processed tile 4650000
# Processed tile 4660000
# Processed tile 4670000
# Processed tile 4680000
# Processed tile 4690000
# Processed tile 4700000
# Processed tile 4710000
# Processed tile 4720000
# Processed tile 4730000
# Processed tile 4740000
# Processed tile 4750000
# Processed tile 4760000
# Processed tile 4770000
# Processed tile 4780000
# Processed tile 4790000
# Processed tile 4800000
# Processed tile 4810000
# Processed tile 4820000
# Processed tile 4830000
# Processed tile 4840000
# Processed tile 4850000
# Processed tile 4860000
# Processed tile 4870000
# Processed tile 4880000
# Processed tile 4890000
# Processed tile 4900000
# Processed tile 4910000
# Processed tile 4920000
# Processed tile 4930000
# Processed tile 4940000
# Processed tile 4950000
# Processed tile 4960000
# Processed tile 4970000
# Processed tile 4980000
# Processed tile 4990000
# Processed tile 5000000
# Processed tile 5010000
# Processed tile 5020000
# Processed tile 5030000
# Processed tile 5040000
# Processed tile 5050000
# Processed tile 5060000
# Processed tile 5070000
# Processed tile 5080000
# Processed tile 5090000
# Processed tile 5100000
# Processed tile 5110000
# Processed tile 5120000
# Processed tile 5130000
# Processed tile 5140000
# Processed tile 5150000
# Processed tile 5160000
# Processed tile 5170000
# Processed tile 5180000
# Processed tile 5190000
# Processed tile 5200000
# Processed tile 5210000
# Processed tile 5220000
# Processed tile 5230000
# Processed tile 5240000
# Processed tile 5250000
# Processed tile 5260000
# Processed tile 5270000
# Processed tile 5280000
# Processed tile 5290000
# Processed tile 5300000
# Processed tile 5310000
# Processed tile 5320000
# Processed tile 5330000
# Processed tile 5340000
# Processed tile 5350000
# Processed tile 5360000
# Processed tile 5370000
# Processed tile 5380000
# Processed tile 5390000
# Processed tile 5400000
# Processed tile 5410000
# Processed tile 5420000
# Processed tile 5430000
# Processed tile 5440000
# Processed tile 5450000
# Processed tile 5460000
# Processed tile 5470000
# Processed tile 5480000
# Processed tile 5490000
# Processed tile 5500000
# Processed tile 5510000
# Processed tile 5520000
# Processed tile 5530000
# Processed tile 5540000
# Processed tile 5550000
# Processed tile 5560000
# Processed tile 5570000
# Processed tile 5580000
# Processed tile 5590000
# Processed tile 5600000
# Processed tile 5610000
# Processed tile 5620000
# Processed tile 5630000
# Processed tile 5640000
# Processed tile 5650000
# Processed tile 5660000
# Processed tile 5670000
# Processed tile 5680000
# Processed tile 5690000
# Processed tile 5700000
# Processed tile 5710000
# Processed tile 5720000
# Processed tile 5730000
# Processed tile 5740000
# Processed tile 5750000
# Processed tile 5760000
# Processed tile 5770000
# Processed tile 5780000
# Processed tile 5790000
# Processed tile 5800000
# Processed tile 5810000
# Processed tile 5820000
# Processed tile 5830000
# Processed tile 5840000
# Processed tile 5850000
# Processed tile 5860000
# Processed tile 5870000
# Processed tile 5880000
# Processed tile 5890000
# Processed tile 5900000
# Processed tile 5910000
# Processed tile 5920000
# Processed tile 5930000
# Processed tile 5940000
# Processed tile 5950000
# Processed tile 5960000
# Processed tile 5970000
# Processed tile 5980000
# Processed tile 5990000
# Processed tile 6000000
# Processed tile 6010000
# Processed tile 6020000
# Processed tile 6030000
# Processed tile 6040000
# Processed tile 6050000
# Processed tile 6060000
# Processed tile 6070000
# Processed tile 6080000
# Processed tile 6090000
# Processed tile 6100000
# Processed tile 6110000
# Processed tile 6120000
# Processed tile 6130000
# Processed tile 6140000
# Processed tile 6150000
# Processed tile 6160000
# Processed tile 6170000
# Processed tile 6180000
# Processed tile 6190000
# Processed tile 6200000
# Processed tile 6210000
# Processed tile 6220000
# Processed tile 6230000
# Processed tile 6240000
# Processed tile 6250000
# Processed tile 6260000
# Processed tile 6270000
# Processed tile 6280000
# Processed tile 6290000
# Processed tile 6300000
# Processed tile 6310000
# Processed tile 6320000
# Processed tile 6330000
# Processed tile 6340000
# Processed tile 6350000
# Processed tile 6360000
# Processed tile 6370000
# Processed tile 6380000
# Processed tile 6390000
# Processed tile 6400000
# Processed tile 6410000
# Processed tile 6420000
# Processed tile 6430000
# Processed tile 6440000
# Processed tile 6450000
# Processed tile 6460000
# Processed tile 6470000
# Processed tile 6480000
# Processed tile 6490000
# Processed tile 6500000
# Processed tile 6510000
# Processed tile 6520000
# Processed tile 6530000
# Processed tile 6540000
# Processed tile 6550000
# Processed tile 6560000
# Processed tile 6570000
# Processed tile 6580000
# Processed tile 6590000
# Processed tile 6600000
# Processed tile 6610000
# Processed tile 6620000
# Processed tile 6630000
# Processed tile 6640000
# Processed tile 6650000
# Processed tile 6660000
# Processed tile 6670000
# Processed tile 6680000
# Processed tile 6690000
# Processed tile 6700000
# Processed tile 6710000
# Processed tile 6720000
# Processed tile 6730000
# Processed tile 6740000
# Processed tile 6750000
# Processed tile 6760000
# Processed tile 6770000
# Processed tile 6780000
# Processed tile 6790000
# Processed tile 6800000
# Processed tile 6810000
# Processed tile 6820000
# Processed tile 6830000
# Processed tile 6840000
# Processed tile 6850000
# Processed tile 6860000
# Processed tile 6870000
# Processed tile 6880000
# Processed tile 6890000
# Processed tile 6900000
# Processed tile 6910000
# Processed tile 6920000
# Processed tile 6930000
# Processed tile 6940000
# Processed tile 6950000
# Processed tile 6960000
# Processed tile 6970000
# Processed tile 6980000
# Processed tile 6990000
# Processed tile 7000000
# Processed tile 7010000
# Processed tile 7020000
# Processed tile 7030000
# Processed tile 7040000
# Processed tile 7050000
# Processed tile 7060000
# Processed tile 7070000
# Processed tile 7080000
# Processed tile 7090000
# Processed tile 7100000
# Processed tile 7110000
# Processed tile 7120000
# Processed tile 7130000
# Processed tile 7140000
# Processed tile 7150000
# Processed tile 7160000
# Processed tile 7170000
# Processed tile 7180000
# Processed tile 7190000
# Processed tile 7200000
# Processed tile 7210000
# Processed tile 7220000
# Processed tile 7230000
# Processed tile 7240000
# Processed tile 7250000
# Processed tile 7260000
# Processed tile 7270000
# Processed tile 7280000
# Processed tile 7290000
# Processed tile 7300000
# Processed tile 7310000
# Processed tile 7320000
# Processed tile 7330000
# Processed tile 7340000
# Processed tile 7350000
# Processed tile 7360000
# Processed tile 7370000
# Processed tile 7380000
# Processed tile 7390000
# Processed tile 7400000
# Processed tile 7410000
# Processed tile 7420000
# Processed tile 7430000
# Processed tile 7440000
# Processed tile 7450000
# Processed tile 7460000
# Processed tile 7470000
# Processed tile 7480000
# Processed tile 7490000
# Processed tile 7500000
# Processed tile 7510000
# Processed tile 7520000
# Processed tile 7530000
# Processed tile 7540000
# Processed tile 7550000
# Processed tile 7560000
# Processed tile 7570000
# Processed tile 7580000
# Processed tile 7590000
# Processed tile 7600000
# Processed tile 7610000
# Processed tile 7620000
# Processed tile 7630000
# Processed tile 7640000
# Processed tile 7650000
# Processed tile 7660000
# Processed tile 7670000
# Processed tile 7680000
# Processed tile 7690000
# Processed tile 7700000
# Processed tile 7710000
# Processed tile 7720000
# Processed tile 7730000
# Processed tile 7740000
# Processed tile 7750000
# Processed tile 7760000
# Processed tile 7770000
# Processed tile 7780000
# Processed tile 7790000
# Processed tile 7800000
# Processed tile 7810000
# Processed tile 7820000
# Processed tile 7830000
# Processed tile 7840000
# Processed tile 7850000
# Processed tile 7860000
# Processed tile 7870000
# Processed tile 7880000
# Processed tile 7890000
# Processed tile 7900000
# Processed tile 7910000
# Processed tile 7920000
# Processed tile 7930000
# Processed tile 7940000
# Processed tile 7950000
# Processed tile 7960000
# Processed tile 7970000
# Processed tile 7980000
# Processed tile 7990000
# Processed tile 8000000
# Processed tile 8010000
# Processed tile 8020000
# Processed tile 8030000
# Processed tile 8040000
# Processed tile 8050000
# Processed tile 8060000
# Processed tile 8070000
# Processed tile 8080000
# Processed tile 8090000
# Processed tile 8100000
# Processed tile 8110000
# Processed tile 8120000
# Processed tile 8130000
# Processed tile 8140000
# Processed tile 8150000
# Processed tile 8160000
# Processed tile 8170000
# Processed tile 8180000
# Processed tile 8190000
# Processed tile 8200000
# Processed tile 8210000
# Processed tile 8220000
# Processed tile 8230000
# Processed tile 8240000
# Processed tile 8250000
# Processed tile 8260000
# Processed tile 8270000
# Processed tile 8280000
# Processed tile 8290000
# Processed tile 8300000
# Processed tile 8310000
# Processed tile 8320000
# Processed tile 8330000
# Processed tile 8340000
# Processed tile 8350000
# Processed tile 8360000
# Processed tile 8370000
# Processed tile 8380000
# Processed tile 8390000
# Processed tile 8400000
# Processed tile 8410000
# Processed tile 8420000
# Processed tile 8430000
# Processed tile 8440000
# Processed tile 8450000
# Processed tile 8460000
# Processed tile 8470000
# Processed tile 8480000
# Processed tile 8490000
# Processed tile 8500000
# Processed tile 8510000
# Processed tile 8520000
# Processed tile 8530000
# Processed tile 8540000
# Processed tile 8550000
# Processed tile 8560000
# Processed tile 8570000
# Processed tile 8580000
# Processed tile 8590000
# Processed tile 8600000
# Processed tile 8610000
# Processed tile 8620000
# Processed tile 8630000
# Processed tile 8640000
# Processed tile 8650000
# Processed tile 8660000
# Processed tile 8670000
# Processed tile 8680000
# Processed tile 8690000
# Processed tile 8700000
# Processed tile 8710000
# Processed tile 8720000
# Processed tile 8730000
# Processed tile 8740000
# Processed tile 8750000
# Processed tile 8760000
# Processed tile 8770000
# Processed tile 8780000
# Processed tile 8790000
# Processed tile 8800000
# Processed tile 8810000
# Processed tile 8820000
# Processed tile 8830000
# Processed tile 8840000
# Processed tile 8850000
# Processed tile 8860000
# Processed tile 8870000
# Processed tile 8880000
# Processed tile 8890000
# Processed tile 8900000
# Processed tile 8910000
# Processed tile 8920000
# Processed tile 8930000
# Processed tile 8940000
# Processed tile 8950000
# Processed tile 8960000
# Processed tile 8970000
# Processed tile 8980000
# Processed tile 8990000
# Processed tile 9000000
# Processed tile 9010000
# Processed tile 9020000
# Processed tile 9030000
# Processed tile 9040000
# Processed tile 9050000
# Processed tile 9060000
# Processed tile 9070000
# Processed tile 9080000
# Processed tile 9090000
# Processed tile 9100000
# Processed tile 9110000
# Processed tile 9120000
# Processed tile 9130000
# Processed tile 9140000
# Processed tile 9150000
# Processed tile 9160000
# Processed tile 9170000
# Processed tile 9180000
# Processed tile 9190000
# Processed tile 9200000
# Processed tile 9210000
# Processed tile 9220000
# Processed tile 9230000
# Processed tile 9240000
# Processed tile 9250000
# Processed tile 9260000
# Processed tile 9270000
# Processed tile 9280000
# Processed tile 9290000
# Processed tile 9300000
# Processed tile 9310000
# Processed tile 9320000
# Processed tile 9330000
# Processed tile 9340000
# Processed tile 9350000
# Processed tile 9360000
# Processed tile 9370000
# Processed tile 9380000
# Processed tile 9390000
# Processed tile 9400000
# Processed tile 9410000
# Processed tile 9420000
# Processed tile 9430000
# Processed tile 9440000
# Processed tile 9450000
# Processed tile 9460000
# Processed tile 9470000
# Processed tile 9480000
# Processed tile 9490000
# Processed tile 9500000
# Processed tile 9510000
# Processed tile 9520000
# Processed tile 9530000
# Processed tile 9540000
# Processed tile 9550000
# Processed tile 9560000
# Processed tile 9570000
# Processed tile 9580000
# Processed tile 9590000
# Processed tile 9600000
# Processed tile 9610000
# Processed tile 9620000
# Processed tile 9630000
# Processed tile 9640000
# Processed tile 9650000
# Processed tile 9660000
# Processed tile 9670000
# Processed tile 9680000
# Processed tile 9690000
# Processed tile 9700000
# Processed tile 9710000
# Processed tile 9720000
# Processed tile 9730000
# Processed tile 9740000
# Processed tile 9750000
# Processed tile 9760000
# Processed tile 9770000
# Processed tile 9780000
# Processed tile 9790000
# Processed tile 9800000
# Processed tile 9810000
# Processed tile 9820000
# Processed tile 9830000
# Processed tile 9840000
# Processed tile 9850000
# Processed tile 9860000
# Processed tile 9870000
# Processed tile 9880000
# Processed tile 9890000
# Processed tile 9900000
# Processed tile 9910000
# Processed tile 9920000
# Processed tile 9930000
# Processed tile 9940000
# Processed tile 9950000
# Processed tile 9960000
# Processed tile 9970000
# Processed tile 9980000
# Processed tile 9990000
# Processed tile 10000000
# Processed tile 10010000
# Processed tile 10020000
# Processed tile 10030000
# Processed tile 10040000
# Processed tile 10050000
# Processed tile 10060000
# Processed tile 10070000
# Processed tile 10080000
# Processed tile 10090000
# Processed tile 10100000
# Processed tile 10110000
# Processed tile 10120000
# Processed tile 10130000
# Processed tile 10140000
# Processed tile 10150000
# Processed tile 10160000
# Processed tile 10170000
# Processed tile 10180000
# Processed tile 10190000
# Processed tile 10200000
# Processed tile 10210000
# Processed tile 10220000
# Processed tile 10230000
# Processed tile 10240000
# Processed tile 10250000
# Processed tile 10260000
# Processed tile 10270000
# Processed tile 10280000
# Processed tile 10290000
# Processed tile 10300000
# Processed tile 10310000
# Processed tile 10320000
# Processed tile 10330000
# Processed tile 10340000
# Processed tile 10350000
# Processed tile 10360000
# Processed tile 10370000
# Processed tile 10380000
# Processed tile 10390000
# Processed tile 10400000
# Processed tile 10410000
# Processed tile 10420000
# Processed tile 10430000
# Processed tile 10440000
# Processed tile 10450000
# Processed tile 10460000
# Processed tile 10470000
# Processed tile 10480000
# Processed tile 10490000
# Processed tile 10500000
# Processed tile 10510000
# Processed tile 10520000
# Processed tile 10530000
# Processed tile 10540000
# Processed tile 10550000
# Processed tile 10560000
# Processed tile 10570000
# Processed tile 10580000
# Processed tile 10590000
# Processed tile 10600000
# Processed tile 10610000
# Processed tile 10620000
# Processed tile 10630000
# Processed tile 10640000
# Processed tile 10650000
# Processed tile 10660000
# Processed tile 10670000
# Processed tile 10680000
# Processed tile 10690000
# Processed tile 10700000
# Processed tile 10710000
# Processed tile 10720000
# Processed tile 10730000
# Processed tile 10740000
# Processed tile 10750000
# Processed tile 10760000
# Processed tile 10770000
# Processed tile 10780000
# Processed tile 10790000
# Processed tile 10800000
# Processed tile 10810000
# Processed tile 10820000
# Processed tile 10830000
# Processed tile 10840000
# Processed tile 10850000
# Processed tile 10860000
# Processed tile 10870000
# Processed tile 10880000
# Processed tile 10890000
# Processed tile 10900000
# Processed tile 10910000
# Processed tile 10920000
# Processed tile 10930000
# Processed tile 10940000
# Processed tile 10950000
# Processed tile 10960000
# Processed tile 10970000
# Processed tile 10980000
# Processed tile 10990000
# Processed tile 11000000
# Processed tile 11010000
# Processed tile 11020000
# Processed tile 11030000
# Processed tile 11040000
# Processed tile 11050000
# Processed tile 11060000
# Processed tile 11070000
# Processed tile 11080000
# Processed tile 11090000
# Processed tile 11100000
# Processed tile 11110000
# Processed tile 11120000
# Processed tile 11130000
# Processed tile 11140000
# Processed tile 11150000
# Processed tile 11160000
# Processed tile 11170000
# Processed tile 11180000
# Processed tile 11190000
# Processed tile 11200000
# Processed tile 11210000
# Processed tile 11220000
# Processed tile 11230000
# Processed tile 11240000
# Processed tile 11250000
# Processed tile 11260000
# Processed tile 11270000
# Processed tile 11280000
# Processed tile 11290000
# Processed tile 11300000
# Processed tile 11310000
# Processed tile 11320000
# Processed tile 11330000
# Processed tile 11340000
# Processed tile 11350000
# Processed tile 11360000
# Processed tile 11370000
# Processed tile 11380000
# Processed tile 11390000
# Processed tile 11400000
# Processed tile 11410000
# Processed tile 11420000
# Processed tile 11430000
# Processed tile 11440000
# Processed tile 11450000
# Processed tile 11460000
# Processed tile 11470000
# Processed tile 11480000
# Processed tile 11490000
# Processed tile 11500000
# Processed tile 11510000
# Processed tile 11520000
# Processed tile 11530000
# Processed tile 11540000
# Processed tile 11550000
# Processed tile 11560000
# Processed tile 11570000
# Processed tile 11580000
# Processed tile 11590000
# Processed tile 11600000
# Processed tile 11610000
# Processed tile 11620000
# Processed tile 11630000
# Processed tile 11640000
# Processed tile 11650000
# Processed tile 11660000
# Processed tile 11670000
# Processed tile 11680000
# Processed tile 11690000
# Processed tile 11700000
# Processed tile 11710000
# Processed tile 11720000
# Processed tile 11730000
# Processed tile 11740000
# Processed tile 11750000
# Processed tile 11760000
# Processed tile 11770000
# Processed tile 11780000
# Processed tile 11790000
# Processed tile 11800000
# Processed tile 11810000
# Processed tile 11820000
# Processed tile 11830000
# Processed tile 11840000
# Processed tile 11850000
# Processed tile 11860000
# Processed tile 11870000
# Processed tile 11880000
# Processed tile 11890000
# Processed tile 11900000
# Processed tile 11910000
# Processed tile 11920000
# Processed tile 11930000
# Processed tile 11940000
# Processed tile 11950000
# Processed tile 11960000
# Processed tile 11970000
# Processed tile 11980000
# Processed tile 11990000
# Processed tile 12000000
# Processed tile 12010000
# Processed tile 12020000
# Processed tile 12030000
# Processed tile 12040000
# Processed tile 12050000
# Processed tile 12060000
# Processed tile 12070000
# Processed tile 12080000
# Processed tile 12090000
# Processed tile 12100000
# Processed tile 12110000
# Processed tile 12120000
# Processed tile 12130000
# Processed tile 12140000
# Processed tile 12150000
# Processed tile 12160000
# Processed tile 12170000
# Processed tile 12180000
# Processed tile 12190000
# Processed tile 12200000
# Processed tile 12210000
# Processed tile 12220000
# Processed tile 12230000
# Processed tile 12240000
# Processed tile 12250000
# Processed tile 12260000
# Processed tile 12270000
# Processed tile 12280000
# Processed tile 12290000
# Processed tile 12300000
# Processed tile 12310000
# Processed tile 12320000
# Processed tile 12330000
# Processed tile 12340000
# Processed tile 12350000
# Processed tile 12360000
# Processed tile 12370000
# Processed tile 12380000
# Processed tile 12390000
# Processed tile 12400000
# Processed tile 12410000
# Processed tile 12420000
# Processed tile 12430000
# Processed tile 12440000
# Processed tile 12450000
# Processed tile 12460000
# Processed tile 12470000
# Processed tile 12480000
# Processed tile 12490000
# Processed tile 12500000
# Processed tile 12510000
# Processed tile 12520000
# Processed tile 12530000
# Processed tile 12540000
# Processed tile 12550000
# Processed tile 12560000
# Processed tile 12570000
# Processed tile 12580000
# Processed tile 12590000
# Processed tile 12600000
# Processed tile 12610000
# Processed tile 12620000
# Processed tile 12630000
# Processed tile 12640000
# Processed tile 12650000
# Processed tile 12660000
# Processed tile 12670000
# Processed tile 12680000
# Processed tile 12690000
# Processed tile 12700000
# Processed tile 12710000
# Processed tile 12720000
# Processed tile 12730000
# Processed tile 12740000
# Processed tile 12750000
# Processed tile 12760000
# Processed tile 12770000
# Processed tile 12780000
# Processed tile 12790000
# Processed tile 12800000
# Processed tile 12810000
# Processed tile 12820000
# Processed tile 12830000
# Processed tile 12840000
# Processed tile 12850000
# Processed tile 12860000
# Processed tile 12870000
# Processed tile 12880000
# Processed tile 12890000
# Processed tile 12900000
# Processed tile 12910000
# Processed tile 12920000
# Processed tile 12930000
# Processed tile 12940000
# Processed tile 12950000
# Processed tile 12960000
# Processed tile 12970000
# Processed tile 12980000
# Processed tile 12990000
# Processed tile 13000000
# Processed tile 13010000
# Processed tile 13020000
# Processed tile 13030000
# Processed tile 13040000
# Processed tile 13050000
# Processed tile 13060000
# Processed tile 13070000
# Processed tile 13080000
# Processed tile 13090000
# Processed tile 13100000
# Processed tile 13110000
# Processed tile 13120000
# Processed tile 13130000
# Processed tile 13140000
# Processed tile 13150000
# Processed tile 13160000
# Processed tile 13170000
# Processed tile 13180000
# Processed tile 13190000
# Processed tile 13200000
# Processed tile 13210000
# Processed tile 13220000
# Processed tile 13230000
# Processed tile 13240000
# Processed tile 13250000
# Processed tile 13260000
# Processed tile 13270000
# Processed tile 13280000
# Processed tile 13290000
# Processed tile 13300000
# Processed tile 13310000
# Processed tile 13320000
# Processed tile 13330000
# Processed tile 13340000
# Processed tile 13350000
# Processed tile 13360000
# Processed tile 13370000
# Processed tile 13380000
# Processed tile 13390000
# Processed tile 13400000
# Processed tile 13410000
# Processed tile 13420000
# Processed tile 13430000
# Processed tile 13440000
# Processed tile 13450000
# Processed tile 13460000
# Processed tile 13470000
# Processed tile 13480000
# Processed tile 13490000
# Processed tile 13500000
# Processed tile 13510000
# Processed tile 13520000
# Processed tile 13530000
# Processed tile 13540000
# Processed tile 13550000
# Processed tile 13560000
# Processed tile 13570000
# Processed tile 13580000
# Processed tile 13590000
# Processed tile 13600000
# Processed tile 13610000
# Processed tile 13620000
# Processed tile 13630000
# Processed tile 13640000
# Processed tile 13650000
# Processed tile 13660000
# Processed tile 13670000
# Processed tile 13680000
# Processed tile 13690000
# Processed tile 13700000
# Processed tile 13710000
# Processed tile 13720000
# Processed tile 13730000
# Processed tile 13740000
# Processed tile 13750000
# Processed tile 13760000
# Processed tile 13770000
# Processed tile 13780000
# Processed tile 13790000
# Processed tile 13800000
# Processed tile 13810000
# Processed tile 13820000
# Processed tile 13830000
# Processed tile 13840000
# Processed tile 13850000
# Processed tile 13860000
# Processed tile 13870000
# Processed tile 13880000
# Processed tile 13890000
# Processed tile 13900000
# Processed tile 13910000
# Processed tile 13920000
# Processed tile 13930000
# Processed tile 13940000
# Processed tile 13950000
# Processed tile 13960000
# Processed tile 13970000
# Processed tile 13980000
# Processed tile 13990000
# Processed tile 14000000
# Processed tile 14010000
# Processed tile 14020000
# Processed tile 14030000
# Processed tile 14040000
# Processed tile 14050000
# Processed tile 14060000
# Processed tile 14070000
# Processed tile 14080000
# Processed tile 14090000
# Processed tile 14100000
# Processed tile 14110000
# Processed tile 14120000
# Processed tile 14130000
# Processed tile 14140000
# Processed tile 14150000
# Processed tile 14160000
# Processed tile 14170000
# Processed tile 14180000
# Processed tile 14190000
# Processed tile 14200000
# Processed tile 14210000
# Processed tile 14220000
# Processed tile 14230000
# Processed tile 14240000
# Processed tile 14250000
# Processed tile 14260000
# Processed tile 14270000
# Processed tile 14280000
# Processed tile 14290000
# Processed tile 14300000
# Processed tile 14310000
# Processed tile 14320000
# Processed tile 14330000
# Processed tile 14340000
# Processed tile 14350000
# Processed tile 14360000
# Processed tile 14370000
# Processed tile 14380000
# Processed tile 14390000
# Processed tile 14400000
# Processed tile 14410000
# Processed tile 14420000
# Processed tile 14430000
# Processed tile 14440000
# Processed tile 14450000
# Processed tile 14460000
# Processed tile 14470000
# Processed tile 14480000
# Processed tile 14490000
# Processed tile 14500000
# Processed tile 14510000
# Processed tile 14520000
# Processed tile 14530000
# Processed tile 14540000
# Processed tile 14550000
# Processed tile 14560000
# Processed tile 14570000
# Processed tile 14580000
# Processed tile 14590000
# Processed tile 14600000
# Processed tile 14610000
# Processed tile 14620000
# Processed tile 14630000
# Processed tile 14640000
# Processed tile 14650000
# Processed tile 14660000
# Processed tile 14670000
# Processed tile 14680000
# Processed tile 14690000
# Processed tile 14700000
# Processed tile 14710000
# Processed tile 14720000
# Processed tile 14730000
# Processed tile 14740000
# Processed tile 14750000
# Processed tile 14760000
# Processed tile 14770000
# Processed tile 14780000
# Processed tile 14790000
# Processed tile 14800000
# Processed tile 14810000
# Processed tile 14820000
# Processed tile 14830000
# Processed tile 14840000
# Processed tile 14850000
# Processed tile 14860000
# Processed tile 14870000
# Processed tile 14880000
# Processed tile 14890000
# Processed tile 14900000
# Processed tile 14910000
# Processed tile 14920000
# Processed tile 14930000
# Processed tile 14940000
# Processed tile 14950000
# Processed tile 14960000
# Processed tile 14970000
# Processed tile 14980000
# Processed tile 14990000
# Processed tile 15000000
# Processed tile 15010000
# Processed tile 15020000
# Processed tile 15030000
# Processed tile 15040000
# Processed tile 15050000
# Processed tile 15060000
# Processed tile 15070000
# Processed tile 15080000
# Processed tile 15090000
# Processed tile 15100000
# Processed tile 15110000
# Processed tile 15120000
# Processed tile 15130000
# Processed tile 15140000
# Processed tile 15150000
# Processed tile 15160000
# Processed tile 15170000
# Processed tile 15180000
# Processed tile 15190000
# Processed tile 15200000
# Processed tile 15210000
# Processed tile 15220000
# Processed tile 15230000
# Processed tile 15240000
# Processed tile 15250000
# Processed tile 15260000
# Processed tile 15270000
# Processed tile 15280000
# Processed tile 15290000
# Processed tile 15300000
# Processed tile 15310000
# Processed tile 15320000
# Processed tile 15330000
# Processed tile 15340000
# Processed tile 15350000
# Processed tile 15360000
# Processed tile 15370000
# Processed tile 15380000
# Processed tile 15390000
# Processed tile 15400000
# Processed tile 15410000
# Processed tile 15420000
# Processed tile 15430000
# Processed tile 15440000
# Processed tile 15450000
# Processed tile 15460000
# Processed tile 15470000
# Processed tile 15480000
# Processed tile 15490000
# Processed tile 15500000
# Processed tile 15510000
# Processed tile 15520000
# Processed tile 15530000
# Processed tile 15540000
# Processed tile 15550000
# Processed tile 15560000
# Processed tile 15570000
# Processed tile 15580000
# Processed tile 15590000
# Processed tile 15600000
# Processed tile 15610000
# Processed tile 15620000
# Processed tile 15630000
# Processed tile 15640000
# Processed tile 15650000
# Processed tile 15660000
# Processed tile 15670000
# Processed tile 15680000
# Processed tile 15690000
# Processed tile 15700000
# Processed tile 15710000
# Processed tile 15720000
# Processed tile 15730000
# Processed tile 15740000
# Processed tile 15750000
# Processed tile 15760000
# Processed tile 15770000
# Processed tile 15780000
# Processed tile 15790000
# Processed tile 15800000
# Processed tile 15810000
# Processed tile 15820000
# Processed tile 15830000
# Processed tile 15840000
# Processed tile 15850000
# Processed tile 15860000
# Processed tile 15870000
# Processed tile 15880000
# Processed tile 15890000
# Processed tile 15900000
# Processed tile 15910000
# Processed tile 15920000
# Processed tile 15930000
# Processed tile 15940000
# Processed tile 15950000
# Processed tile 15960000
# Processed tile 15970000
# Processed tile 15980000
# Processed tile 15990000
# Processed tile 16000000
# Processed tile 16010000
# Processed tile 16020000
# Processed tile 16030000
# Processed tile 16040000
# Processed tile 16050000
# Processed tile 16060000
# Processed tile 16070000
# Processed tile 16080000
# Processed tile 16090000
# Processed tile 16100000
# Processed tile 16110000
# Processed tile 16120000
# Processed tile 16130000
# Processed tile 16140000
# Processed tile 16150000
# Processed tile 16160000
# Processed tile 16170000
# Processed tile 16180000
# Processed tile 16190000
# Processed tile 16200000
# Processed tile 16210000
# Processed tile 16220000
# Processed tile 16230000
# Processed tile 16240000
# Processed tile 16250000
# Processed tile 16260000
# Processed tile 16270000
# Processed tile 16280000
# Processed tile 16290000
# Processed tile 16300000
# Processed tile 16310000
# Processed tile 16320000
# Processed tile 16330000
# Processed tile 16340000
# Processed tile 16350000
# Processed tile 16360000
# Processed tile 16370000
# Processed tile 16380000
# Processed tile 16390000
# Processed tile 16400000
# Processed tile 16410000
# Processed tile 16420000
# Processed tile 16430000
# Processed tile 16440000
# Processed tile 16450000
# Processed tile 16460000
# Processed tile 16470000
# Processed tile 16480000
# Processed tile 16490000
# Processed tile 16500000
# Processed tile 16510000
# Processed tile 16520000
# Processed tile 16530000
# Processed tile 16540000
# Processed tile 16550000
# Processed tile 16560000
# Processed tile 16570000
# Processed tile 16580000
# Processed tile 16590000
# Processed tile 16600000
# Processed tile 16610000
# Processed tile 16620000
# Processed tile 16630000
# Processed tile 16640000
# Processed tile 16650000
# Processed tile 16660000
# Processed tile 16670000
# Processed tile 16680000
# Processed tile 16690000
# Processed tile 16700000
# Processed tile 16710000
# Processed tile 16720000
# Processed tile 16730000
# Processed tile 16740000
# Processed tile 16750000
# Processed tile 16760000
# Processed tile 16770000
# Processed tile 16780000
# Processed tile 16790000
# Processed tile 16800000
# Processed tile 16810000
# Processed tile 16820000
# Processed tile 16830000
# Processed tile 16840000
# Processed tile 16850000
# Processed tile 16860000
# Processed tile 16870000
# Processed tile 16880000
# Processed tile 16890000
# Processed tile 16900000
# Processed tile 16910000
# Processed tile 16920000
# Processed tile 16930000
# Processed tile 16940000
# Processed tile 16950000
# Processed tile 16960000
# Processed tile 16970000
# Processed tile 16980000
# Processed tile 16990000
# Processed tile 17000000
# Processed tile 17010000
# Processed tile 17020000
# Processed tile 17030000
# Processed tile 17040000
# Processed tile 17050000
# Processed tile 17060000
# Processed tile 17070000
# Processed tile 17080000
# Processed tile 17090000
# Processed tile 17100000
# Processed tile 17110000
# Processed tile 17120000
# Processed tile 17130000
# Processed tile 17140000
# Processed tile 17150000
# Processed tile 17160000
# Processed tile 17170000
# Processed tile 17180000
# Processed tile 17190000
# Processed tile 17200000
# Processed tile 17210000
# Processed tile 17220000
# Processed tile 17230000
# Processed tile 17240000
# Processed tile 17250000
# Processed tile 17260000
# Processed tile 17270000
# Processed tile 17280000
# Processed tile 17290000
# Processed tile 17300000
# Processed tile 17310000
# Processed tile 17320000
# Processed tile 17330000
# Processed tile 17340000
# Processed tile 17350000
# Processed tile 17360000
# Processed tile 17370000
# Processed tile 17380000
# Processed tile 17390000
# Processed tile 17400000
# Processed tile 17410000
# Processed tile 17420000
# Processed tile 17430000
# Processed tile 17440000
# Processed tile 17450000
# Processed tile 17460000
# Processed tile 17470000
# Processed tile 17480000
# Processed tile 17490000
# Processed tile 17500000
# Processed tile 17510000
# Processed tile 17520000
# Processed tile 17530000
# Processed tile 17540000
# Processed tile 17550000
# Processed tile 17560000
# Processed tile 17570000
# Processed tile 17580000
# Processed tile 17590000
# Processed tile 17600000
# Processed tile 17610000
# Processed tile 17620000
# Processed tile 17630000
# Processed tile 17640000
# Processed tile 17650000
# Processed tile 17660000
# Processed tile 17670000
# Processed tile 17680000
# Processed tile 17690000
# Processed tile 17700000
# Processed tile 17710000
# Processed tile 17720000
# Processed tile 17730000
# Processed tile 17740000
# Processed tile 17750000
# Processed tile 17760000
# Processed tile 17770000
# Processed tile 17780000
# Processed tile 17790000
# Processed tile 17800000
# Processed tile 17810000
# Processed tile 17820000
# Processed tile 17830000
# Processed tile 17840000
# Processed tile 17850000
# Processed tile 17860000
# Processed tile 17870000
# Processed tile 17880000
# Processed tile 17890000
# Processed tile 17900000
# Processed tile 17910000
# Processed tile 17920000
# Processed tile 17930000
# Processed tile 17940000
# Processed tile 17950000
# Processed tile 17960000
# Processed tile 17970000
# Processed tile 17980000
# Processed tile 17990000
# Processed tile 18000000
# Processed tile 18010000
# Processed tile 18020000
# Processed tile 18030000
# Processed tile 18040000
# Processed tile 18050000
# Processed tile 18060000
# Processed tile 18070000
# Processed tile 18080000
# Processed tile 18090000
# Processed tile 18100000
# Processed tile 18110000
# Processed tile 18120000
# Processed tile 18130000
# Processed tile 18140000
# Processed tile 18150000
# Processed tile 18160000
# Processed tile 18170000
# Processed tile 18180000
# Processed tile 18190000
# Processed tile 18200000
# Processed tile 18210000
# Processed tile 18220000
# Processed tile 18230000
# Processed tile 18240000
# Processed tile 18250000
# Processed tile 18260000
# Processed tile 18270000
# Processed tile 18280000
# Processed tile 18290000
# Processed tile 18300000
# Processed tile 18310000
# Processed tile 18320000
# Processed tile 18330000
# Processed tile 18340000
# Processed tile 18350000
# Processed tile 18360000
# Processed tile 18370000
# Processed tile 18380000
# Processed tile 18390000
# Processed tile 18400000
# Processed tile 18410000
# Processed tile 18420000
# Processed tile 18430000
# Processed tile 18440000
# Processed tile 18450000
# Processed tile 18460000
# Processed tile 18470000
# Processed tile 18480000
# Processed tile 18490000
# Processed tile 18500000
# Processed tile 18510000
# Processed tile 18520000
# Processed tile 18530000
# Processed tile 18540000
# Processed tile 18550000
# Processed tile 18560000
# Processed tile 18570000
# Processed tile 18580000
# Processed tile 18590000
# Processed tile 18600000
# Processed tile 18610000
# Processed tile 18620000
# Processed tile 18630000
# Processed tile 18640000
# Processed tile 18650000
# Processed tile 18660000
# Processed tile 18670000
# Processed tile 18680000
# Processed tile 18690000
# Processed tile 18700000
# Processed tile 18710000
# Processed tile 18720000
# Processed tile 18730000
# Processed tile 18740000
# Processed tile 18750000
# Processed tile 18760000
# Processed tile 18770000
# Processed tile 18780000
# Processed tile 18790000
# Processed tile 18800000
# Processed tile 18810000
# Processed tile 18820000
# Processed tile 18830000
# Processed tile 18840000
# Processed tile 18850000
# Processed tile 18860000
# Processed tile 18870000
# Processed tile 18880000
# Processed tile 18890000
# Processed tile 18900000
# Processed tile 18910000
# Processed tile 18920000
# Processed tile 18930000
# Processed tile 18940000
# Processed tile 18950000
# Processed tile 18960000
# Processed tile 18970000
# Processed tile 18980000
# Processed tile 18990000
# Processed tile 19000000
# Processed tile 19010000
# Processed tile 19020000
# Processed tile 19030000
# Processed tile 19040000
# Processed tile 19050000
# Processed tile 19060000
# Processed tile 19070000
# Processed tile 19080000
# Processed tile 19090000
# Processed tile 19100000
# Processed tile 19110000
# Processed tile 19120000
# Processed tile 19130000
# Processed tile 19140000
# Processed tile 19150000
# Processed tile 19160000
# Processed tile 19170000
# Processed tile 19180000
# Processed tile 19190000
# Processed tile 19200000
# Processed tile 19210000
# Processed tile 19220000
# Processed tile 19230000
# Processed tile 19240000
# Processed tile 19250000
# Processed tile 19260000
# Processed tile 19270000
# Processed tile 19280000
# Processed tile 19290000
# Processed tile 19300000
# Processed tile 19310000
# Processed tile 19320000
# Processed tile 19330000
# Processed tile 19340000
# Processed tile 19350000
# Processed tile 19360000
# Processed tile 19370000
# Processed tile 19380000
# Processed tile 19390000
# Processed tile 19400000
# Processed tile 19410000
# Processed tile 19420000
# Processed tile 19430000
# Processed tile 19440000
# Processed tile 19450000
# Processed tile 19460000
# Processed tile 19470000
# Processed tile 19480000
# Processed tile 19490000
# Processed tile 19500000
# Processed tile 19510000
# Processed tile 19520000
# Processed tile 19530000
# Processed tile 19540000
# Processed tile 19550000
# Processed tile 19560000
# Processed tile 19570000
# Processed tile 19580000
# Processed tile 19590000
# Processed tile 19600000
# Processed tile 19610000
# Processed tile 19620000
# Processed tile 19630000
# Processed tile 19640000
# Processed tile 19650000
# Processed tile 19660000
# Processed tile 19670000
# Processed tile 19680000
# Processed tile 19690000
# Processed tile 19700000
# Processed tile 19710000
# Processed tile 19720000
# Processed tile 19730000
# Processed tile 19740000
# Processed tile 19750000
# Processed tile 19760000
# Processed tile 19770000
# Processed tile 19780000
# Processed tile 19790000
# Processed tile 19800000
# Processed tile 19810000
# Processed tile 19820000
# Processed tile 19830000
# Processed tile 19840000
# Processed tile 19850000
# Processed tile 19860000
# Processed tile 19870000
# Processed tile 19880000
# Processed tile 19890000
# Processed tile 19900000
# Processed tile 19910000
# Processed tile 19920000
# Processed tile 19930000
# Processed tile 19940000
# Processed tile 19950000
# Processed tile 19960000
# Processed tile 19970000
# Processed tile 19980000
# Processed tile 19990000
# Processed tile 20000000
# Processed tile 20010000
# Processed tile 20020000
# Processed tile 20030000
# Processed tile 20040000
# Processed tile 20050000
# Processed tile 20060000
# Processed tile 20070000
# Processed tile 20080000
# Processed tile 20090000
# Processed tile 20100000
# Processed tile 20110000
# Processed tile 20120000
# Processed tile 20130000
# Processed tile 20140000
# Processed tile 20150000
# Processed tile 20160000
# Processed tile 20170000
# Processed tile 20180000
# Processed tile 20190000
# Processed tile 20200000
# Processed tile 20210000
# Processed tile 20220000
# Processed tile 20230000
# Processed tile 20240000
# Processed tile 20250000
# Processed tile 20260000
# Processed tile 20270000
# Processed tile 20280000
# Processed tile 20290000
# Processed tile 20300000
# Processed tile 20310000
# Processed tile 20320000
# Processed tile 20330000
# Processed tile 20340000
# Processed tile 20350000
# Processed tile 20360000
# Processed tile 20370000
# Processed tile 20380000
# Processed tile 20390000
# Processed tile 20400000
# Processed tile 20410000
# Processed tile 20420000
# Processed tile 20430000
# Processed tile 20440000
# Processed tile 20450000
# ...
# Processed tile 35830000
# Processed tile 35840000
# Processed tile 35850000
# Processed tile 35860000
# Processed tile 35870000
# Processed tile 35880000
# Processed tile 35890000
# Processed tile 35900000
# Processed tile 35910000
# Processed tile 35920000
# Processed tile 35930000
# Processed tile 35940000
# Processed tile 35950000
# Processed tile 35960000
# Processed tile 35970000
# Processed tile 35980000
# Processed tile 35990000
# Processed tile 36000000
# Processed tile 36010000
# Processed tile 36020000
# Processed tile 36030000
# Processed tile 36040000
# Processed tile 36050000
# Processed tile 36060000
# Processed tile 36070000
# Processed tile 36080000
# Processed tile 36090000
# Processed tile 36100000
# Processed tile 36110000
# Processed tile 36120000
# Processed tile 36130000
# Processed tile 36140000
# Processed tile 36150000
# Processed tile 36160000
# Processed tile 36170000
# Processed tile 36180000
# Processed tile 36190000
# Processed tile 36200000
# Processed tile 36210000
# Processed tile 36220000
# Processed tile 36230000
# Processed tile 36240000
# Processed tile 36250000
# Processed tile 36260000
# Processed tile 36270000
# Processed tile 36280000
# Processed tile 36290000
# Processed tile 36300000
# Processed tile 36310000
# Processed tile 36320000
# Processed tile 36330000
# Processed tile 36340000
# Processed tile 36350000
# Processed tile 36360000
# Processed tile 36370000
# Processed tile 36380000
# Processed tile 36390000
# Processed tile 36400000
# Processed tile 36410000
# Processed tile 36420000
# Processed tile 36430000
# Processed tile 36440000
# Processed tile 36450000
# Processed tile 36460000
# Processed tile 36470000
# Processed tile 36480000
# Processed tile 36490000
# Processed tile 36500000
# Processed tile 36510000
# Processed tile 36520000
# Processed tile 36530000
# Processed tile 36540000
# Processed tile 36550000
# Processed tile 36560000
# Processed tile 36570000
# Processed tile 36580000
# Processed tile 36590000
# Processed tile 36600000
# Processed tile 36610000
# Processed tile 36620000
# Processed tile 36630000
# Processed tile 36640000
# Processed tile 36650000
# Processed tile 36660000
# Processed tile 36670000
# Processed tile 36680000
# Processed tile 36690000
# Processed tile 36700000
# Processed tile 36710000
# Processed tile 36720000
# Processed tile 36730000
# Processed tile 36740000
# Processed tile 36750000
# Processed tile 36760000
# Processed tile 36770000
# Processed tile 36780000
# Processed tile 36790000
# Processed tile 36800000
# Processed tile 36810000
# Processed tile 36820000
# Processed tile 36830000
# Processed tile 36840000
# Processed tile 36850000
# Processed tile 36860000
# Processed tile 36870000
# Processed tile 36880000
# Processed tile 36890000
# Processed tile 36900000
# Processed tile 36910000
# Processed tile 36920000
# Processed tile 36930000
# Processed tile 36940000
# Processed tile 36950000
# Processed tile 36960000
# Processed tile 36970000
# Processed tile 36980000
# Processed tile 36990000
# Processed tile 37000000
# Processed tile 37010000
# Processed tile 37020000
# Processed tile 37030000
# Processed tile 37040000
# Processed tile 37050000
# Processed tile 37060000
# Processed tile 37070000
# Processed tile 37080000
# Processed tile 37090000
# Processed tile 37100000
# Processed tile 37110000
# Processed tile 37120000
# Processed tile 37130000
# Processed tile 37140000
# Processed tile 37150000
# Processed tile 37160000
# Processed tile 37170000
# Processed tile 37180000
# Processed tile 37190000
# Processed tile 37200000
# Processed tile 37210000
# Processed tile 37220000
# Processed tile 37230000
# Processed tile 37240000
# Processed tile 37250000
# Processed tile 37260000
# Processed tile 37270000
# Processed tile 37280000
# Processed tile 37290000
# Processed tile 37300000
# Processed tile 37310000
# Processed tile 37320000
# Processed tile 37330000
# Processed tile 37340000
# Processed tile 37350000
# Processed tile 37360000
# Processed tile 37370000
# Processed tile 37380000
# Processed tile 37390000
# Processed tile 37400000
# Processed tile 37410000
# Processed tile 37420000
# Processed tile 37430000
# Processed tile 37440000
# Processed tile 37450000
# Processed tile 37460000
# Processed tile 37470000
# Processed tile 37480000
# Processed tile 37490000
# Processed tile 37500000
# Processed tile 37510000
# Processed tile 37520000
# Processed tile 37530000
# Processed tile 37540000
# Processed tile 37550000
# Processed tile 37560000
# Processed tile 37570000
# Processed tile 37580000
# Processed tile 37590000
# Processed tile 37600000
# Processed tile 37610000
# Processed tile 37620000
# Processed tile 37630000
# Processed tile 37640000
# Processed tile 37650000
# Processed tile 37660000
# Processed tile 37670000
# Processed tile 37680000
# Processed tile 37690000
# Processed tile 37700000
# Processed tile 37710000
# Processed tile 37720000
# Processed tile 37730000
# Processed tile 37740000
# Processed tile 37750000
# Processed tile 37760000
# Processed tile 37770000
# Processed tile 37780000
# Processed tile 37790000
# Processed tile 37800000
# Processed tile 37810000
# Processed tile 37820000
# Processed tile 37830000
# Processed tile 37840000
# Processed tile 37850000
# Processed tile 37860000
# Processed tile 37870000
# Processed tile 37880000
# Processed tile 37890000
# Processed tile 37900000
# Processed tile 37910000
# Processed tile 37920000
# Processed tile 37930000
# Processed tile 37940000
# Processed tile 37950000
# Processed tile 37960000
# Processed tile 37970000
# Processed tile 37980000
# Processed tile 37990000
# Processed tile 38000000
# Processed tile 38010000
# Processed tile 38020000
# Processed tile 38030000
# Processed tile 38040000
# Processed tile 38050000
# Processed tile 38060000
# Processed tile 38070000
# Processed tile 38080000
# Processed tile 38090000
# Processed tile 38100000
# Processed tile 38110000
# Processed tile 38120000
# Processed tile 38130000
# Processed tile 38140000
# Processed tile 38150000
# Processed tile 38160000
# Processed tile 38170000
# Processed tile 38180000
# Processed tile 38190000
# Processed tile 38200000
# Processed tile 38210000
# Processed tile 38220000
# Processed tile 38230000
# Processed tile 38240000
# Processed tile 38250000
# Processed tile 38260000
# Processed tile 38270000
# Processed tile 38280000
# Processed tile 38290000
# Processed tile 38300000
# Processed tile 38310000
# Processed tile 38320000
# Processed tile 38330000
# Processed tile 38340000
# Processed tile 38350000
# Processed tile 38360000
# Processed tile 38370000
# Processed tile 38380000
# Processed tile 38390000
# Processed tile 38400000
# Processed tile 38410000
# Processed tile 38420000
# Processed tile 38430000
# Processed tile 38440000
# Processed tile 38450000
# Processed tile 38460000
# Processed tile 38470000
# Processed tile 38480000
# Processed tile 38490000
# Processed tile 38500000
# Processed tile 38510000
# Processed tile 38520000
# Processed tile 38530000
# Processed tile 38540000
# Processed tile 38550000
# Processed tile 38560000
# Processed tile 38570000
# Processed tile 38580000
# Processed tile 38590000
# Processed tile 38600000
# Processed tile 38610000
# Processed tile 38620000
# Processed tile 38630000
# Processed tile 38640000
# Processed tile 38650000
# Processed tile 38660000
# Processed tile 38670000
# Processed tile 38680000
# Processed tile 38690000
# Processed tile 38700000
# Processed tile 38710000
# Processed tile 38720000
# Processed tile 38730000
# Processed tile 38740000
# Processed tile 38750000
# Processed tile 38760000
# Processed tile 38770000
# Processed tile 38780000
# Processed tile 38790000
# Processed tile 38800000
# Processed tile 38810000
# Processed tile 38820000
# Processed tile 38830000
# Processed tile 38840000
# Processed tile 38850000
# Processed tile 38860000
# Processed tile 38870000
# Processed tile 38880000
# Processed tile 38890000
# Processed tile 38900000
# Processed tile 38910000
# Processed tile 38920000
# Processed tile 38930000
# Processed tile 38940000
# Processed tile 38950000
# Processed tile 38960000
# Processed tile 38970000
# Processed tile 38980000
# Processed tile 38990000
# Processed tile 39000000
# Processed tile 39010000
# Processed tile 39020000
# Processed tile 39030000
# Processed tile 39040000
# Processed tile 39050000
# Processed tile 39060000
# Processed tile 39070000
# Processed tile 39080000
# Processed tile 39090000
# Processed tile 39100000
# Processed tile 39110000
# Processed tile 39120000
# Processed tile 39130000
# Processed tile 39140000
# Processed tile 39150000
# Processed tile 39160000
# Processed tile 39170000
# Processed tile 39180000
# Processed tile 39190000
# Processed tile 39200000
# Processed tile 39210000
# Processed tile 39220000
# Processed tile 39230000
# Processed tile 39240000
# Processed tile 39250000
# Processed tile 39260000
# Processed tile 39270000
# Processed tile 39280000
# Processed tile 39290000
# Processed tile 39300000
# Processed tile 39310000
# Processed tile 39320000
# Processed tile 39330000
# Processed tile 39340000
# Processed tile 39350000
# Processed tile 39360000
# Processed tile 39370000
# Processed tile 39380000
# Processed tile 39390000
# Processed tile 39400000
# Processed tile 39410000
# Processed tile 39420000
# Processed tile 39430000
# Processed tile 39440000
# Processed tile 39450000
# Processed tile 39460000
# Processed tile 39470000
# Processed tile 39480000
# Processed tile 39490000
# Processed tile 39500000
# Processed tile 39510000
# Processed tile 39520000
# Processed tile 39530000
# Processed tile 39540000
# Processed tile 39550000
# Processed tile 39560000
# Processed tile 39570000
# Processed tile 39580000
# Processed tile 39590000
# Processed tile 39600000
# Processed tile 39610000
# Processed tile 39620000
# Processed tile 39630000
# Processed tile 39640000
# Processed tile 39650000
# Processed tile 39660000
# Processed tile 39670000
# Processed tile 39680000
# Processed tile 39690000
# Processed tile 39700000
# Processed tile 39710000
# Processed tile 39720000
# Processed tile 39730000
# Processed tile 39740000
# Processed tile 39750000
# Processed tile 39760000
# Processed tile 39770000
# Processed tile 39780000
# Processed tile 39790000
# Processed tile 39800000
# Processed tile 39810000
# Processed tile 39820000
# Processed tile 39830000
# Processed tile 39840000
# Processed tile 39850000
# Processed tile 39860000
# Processed tile 39870000
# Processed tile 39880000
# Processed tile 39890000
# Processed tile 39900000
# Processed tile 39910000
# Processed tile 39920000
# Processed tile 39930000
# Processed tile 39940000
# Processed tile 39950000
# Processed tile 39960000
# Processed tile 39970000
# Processed tile 39980000
# Processed tile 39990000
# Processed tile 40000000
# Processed tile 40010000
# Processed tile 40020000
# Processed tile 40030000
# Processed tile 40040000
# Processed tile 40050000
# Processed tile 40060000
# Processed tile 40070000
# Processed tile 40080000
# Processed tile 40090000
# Processed tile 40100000
# Processed tile 40110000
# Processed tile 40120000
# Processed tile 40130000
# Processed tile 40140000
# Processed tile 40150000
# Processed tile 40160000
# Processed tile 40170000
# Processed tile 40180000
# Processed tile 40190000
# Processed tile 40200000
# Processed tile 40210000
# Processed tile 40220000
# Processed tile 40230000
# Processed tile 40240000
# Processed tile 40250000
# Processed tile 40260000
# Processed tile 40270000
# Processed tile 40280000
# Processed tile 40290000
# Processed tile 40300000
# Processed tile 40310000
# Processed tile 40320000
# Processed tile 40330000
# Processed tile 40340000
# Processed tile 40350000
# Processed tile 40360000
# Processed tile 40370000
# Processed tile 40380000
# Processed tile 40390000
# Processed tile 40400000
# Processed tile 40410000
# Processed tile 40420000
# Processed tile 40430000
# Processed tile 40440000
# Processed tile 40450000
# Processed tile 40460000
# Processed tile 40470000
# Processed tile 40480000
# Processed tile 40490000
# Processed tile 40500000
# Processed tile 40510000
# Processed tile 40520000
# Processed tile 40530000
# Processed tile 40540000
# Processed tile 40550000
# Processed tile 40560000
# Processed tile 40570000
# Processed tile 40580000
# Processed tile 40590000
# Processed tile 40600000
# Processed tile 40610000
# Processed tile 40620000
# Processed tile 40630000
# Processed tile 40640000
# Processed tile 40650000
# Processed tile 40660000
# Processed tile 40670000
# Processed tile 40680000
# Processed tile 40690000
# Processed tile 40700000
# Processed tile 40710000
# Processed tile 40720000
# Processed tile 40730000
# Processed tile 40740000
# Processed tile 40750000
# Processed tile 40760000
# Processed tile 40770000
# Processed tile 40780000
# Processed tile 40790000
# Processed tile 40800000
# Processed tile 40810000
# Processed tile 40820000
# Processed tile 40830000
# Processed tile 40840000
# Processed tile 40850000
# Processed tile 40860000
# Processed tile 40870000
# Processed tile 40880000
# Processed tile 40890000
# Processed tile 40900000
# Processed tile 40910000
# Processed tile 40920000
# Processed tile 40930000
# Processed tile 40940000
# Processed tile 40950000
# Processed tile 40960000
# Processed tile 40970000
# Processed tile 40980000
# Processed tile 40990000
# Processed tile 41000000
# Processed tile 41010000
# Processed tile 41020000
# Processed tile 41030000
# Processed tile 41040000
# Processed tile 41050000
# Processed tile 41060000
# Processed tile 41070000
# Processed tile 41080000
# Processed tile 41090000
# Processed tile 41100000
# Processed tile 41110000
# Processed tile 41120000
# Processed tile 41130000
# Processed tile 41140000
# Processed tile 41150000
# Processed tile 41160000
# Processed tile 41170000
# Processed tile 41180000
# Processed tile 41190000
# Processed tile 41200000
# Processed tile 41210000
# Processed tile 41220000
# Processed tile 41230000
# Processed tile 41240000
# Processed tile 41250000
# Processed tile 41260000
# Processed tile 41270000
# Processed tile 41280000
# Processed tile 41290000
# Processed tile 41300000
# Processed tile 41310000
# Processed tile 41320000
# Processed tile 41330000
# Processed tile 41340000
# Processed tile 41350000
# Processed tile 41360000
# Processed tile 41370000
# Processed tile 41380000
# Processed tile 41390000
# Processed tile 41400000
# Processed tile 41410000
# Processed tile 41420000
# Processed tile 41430000
# Processed tile 41440000
# Processed tile 41450000
# Processed tile 41460000
# Processed tile 41470000
# Processed tile 41480000
# Processed tile 41490000
# Processed tile 41500000
# Processed tile 41510000
# Processed tile 41520000
# Processed tile 41530000
# Processed tile 41540000
# Processed tile 41550000
# Processed tile 41560000
# Processed tile 41570000
# Processed tile 41580000
# Processed tile 41590000
# Processed tile 41600000
# Processed tile 41610000
# Processed tile 41620000
# Processed tile 41630000
# Processed tile 41640000
# Processed tile 41650000
# Processed tile 41660000
# Processed tile 41670000
# Processed tile 41680000
# Processed tile 41690000
# Processed tile 41700000
# Processed tile 41710000
# Processed tile 41720000
# Processed tile 41730000
# Processed tile 41740000
# Processed tile 41750000
# Processed tile 41760000
# Processed tile 41770000
# Processed tile 41780000
# Processed tile 41790000
# Processed tile 41800000
# Processed tile 41810000
# Processed tile 41820000
# Processed tile 41830000
# Processed tile 41840000
# Processed tile 41850000
# Processed tile 41860000
# Processed tile 41870000
# Processed tile 41880000
# Processed tile 41890000
# Processed tile 41900000
# Processed tile 41910000
# Processed tile 41920000
# Processed tile 41930000
# Processed tile 41940000
# Processed tile 41950000
# Processed tile 41960000
# Processed tile 41970000
# Processed tile 41980000
# Processed tile 41990000
# Processed tile 42000000
# Processed tile 42010000
# Processed tile 42020000
# Processed tile 42030000
# Processed tile 42040000
# Processed tile 42050000
# Processed tile 42060000
# Processed tile 42070000
# Processed tile 42080000
# Processed tile 42090000
# Processed tile 42100000
# Processed tile 42110000
# Processed tile 42120000
# Processed tile 42130000
# Processed tile 42140000
# Processed tile 42150000
# Processed tile 42160000
# Processed tile 42170000
# Processed tile 42180000
# Processed tile 42190000
# Processed tile 42200000
# Processed tile 42210000
# Processed tile 42220000
# Processed tile 42230000
# Processed tile 42240000
# Processed tile 42250000
# Processed tile 42260000
# Processed tile 42270000
# Processed tile 42280000
# Processed tile 42290000
# Processed tile 42300000
# Processed tile 42310000
# Processed tile 42320000
# Processed tile 42330000
# Processed tile 42340000
# Processed tile 42350000
# Processed tile 42360000
# Processed tile 42370000
# Processed tile 42380000
# Processed tile 42390000
# Processed tile 42400000
# Processed tile 42410000
# Processed tile 42420000
# Processed tile 42430000
# Processed tile 42440000
# Processed tile 42450000
# Processed tile 42460000
# Processed tile 42470000
# ---
# Tile creation took 448m 24s

# %%
# TILING SNIMKU + REFERENCIE NA 32X32 STRIDE 32 NA NATRENOVANIE A VALIDOVANIE MODELU

# SETTINGS
image_path = r"composite_subset_with_height.tif"  # Path to Sentinel image (features)
reference_path = r"berlin_lcz_GT_fullres.tif"  # Path to reference raster (labels)
patch_size = 32
stride = 32
offset_left = 2
offset_top = 2
output_dir_all = r"32x32_stride32_left2_top2_all"
output_dir_valid = r"32x32_stride32_left2_top2_GT"

start = time.time()
class PatchDataset(Dataset):
    def __init__(self, image_path, reference_path, patch_size, stride, offset_left=0, offset_top=0):
        """
        Dataset for extracting patches from an image and corresponding labels from a reference raster.

        Args:
            image_path (str): Path to the Sentinel image (features).
            reference_path (str): Path to the reference raster (labels).
            patch_size (int): Size of the square patches (in pixels).
            stride (int): Step size for sliding the window.
            offset_left (int): Number of pixels to ignore from the left edge of the image.
            offset_top (int): Number of pixels to ignore from the top edge of the image.
        """
        self.image_path = image_path
        self.reference_path = reference_path
        self.patch_size = patch_size
        self.stride = stride
        self.offset_left = offset_left
        self.offset_top = offset_top

        # Open the feature and reference rasters
        self.src_features = rio.open(image_path)
        self.src_labels = rio.open(reference_path)

        # Ensure the dimensions match
        assert (
            self.src_features.width == self.src_labels.width
            and self.src_features.height == self.src_labels.height
        ), "Image and reference dimensions do not match!"

        # Adjust dimensions based on offsets
        self.width = self.src_features.width - offset_left
        self.height = self.src_features.height - offset_top
        self.num_bands = self.src_features.count

        # Precompute patch positions (accounting for offsets)
        self.patches = [
            (row, col)
            for row in range(0, self.height - patch_size + 1, stride)
            for col in range(0, self.width - patch_size + 1, stride)
        ]

    def __len__(self):
        return len(self.patches)

    def __getitem__(self, idx):
        row, col = self.patches[idx]

        # Adjust row and col to account for offsets
        row += self.offset_top
        col += self.offset_left

        # Extract the image patch
        window = rio.windows.Window(col, row, self.patch_size, self.patch_size)
        patch_features = self.src_features.read(window=window)  # Shape: (bands, patch_size, patch_size)

        # Extract the central pixel from the reference raster
        center_row = row + self.patch_size // 2
        center_col = col + self.patch_size // 2
        central_window = rio.windows.Window(center_col, center_row, 1, 1)
        label = self.src_labels.read(1, window=central_window).item()  # Read as scalar

        # Return the patch and its label
        return torch.tensor(patch_features, dtype=torch.float32), label

# Create output directories
os.makedirs(output_dir_all, exist_ok=True)
os.makedirs(output_dir_valid, exist_ok=True)

# Initialize the dataset
dataset = PatchDataset(
    image_path=image_path, 
    reference_path=reference_path, 
    patch_size=patch_size, 
    stride=stride,
    offset_left=offset_left, 
    offset_top=offset_top
)

# Save all tiles and valid tiles
valid_tile_paths = []  # To store paths to valid tiles
labels_list = []       # To store corresponding labels

for idx, (features, label) in enumerate(dataset):
    # Save every generated tile
    all_tile_path = os.path.join(output_dir_all, f"tile_{str(idx).zfill(20)}.pt")
    torch.save(features, all_tile_path)

    # Save only valid tiles (label != 0)
    if label != 0:
        valid_tile_path = os.path.join(output_dir_valid, f"tile_{str(idx).zfill(20)}.pt")
        torch.save(features, valid_tile_path)
        valid_tile_paths.append(valid_tile_path)
        labels_list.append(label)

    # Log progress
    if idx % 10000 == 0:
        print(f"Processed tile {idx}")

# Save labels for valid tiles
labels_tensor = torch.tensor(labels_list, dtype=torch.long)
torch.save(labels_tensor, os.path.join(output_dir_valid, "labels.pt"))


print(f"Saved {len(valid_tile_paths)} valid tiles to '{output_dir_valid}'.")
print(f"Saved all tiles to '{output_dir_all}'.")

print('---')
time_elapsed = time.time() - start
print('Tile creation took {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
# Out:
# Processed tile 0
# Processed tile 10000
# Processed tile 20000
# Processed tile 30000
# Processed tile 40000
# Saved 2404 valid tiles to '32x32_stride32_left2_top2_GT'.
# Saved all tiles to '32x32_stride32_left2_top2_all'.
# ---
# Tile creation took 4m 33s
